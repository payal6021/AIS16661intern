# %% [markdown]
# #       >>>>>>      SEABORN LIBRARY

# %% [markdown]
# # Seaborn is a Python data visualization library based on Matplotlib that provides a high-level interface for drawing attractive and informative statistical graphics. It is designed to make it easier to create complex plots and explore datasets. Here are some key features and capabilities of Seaborn:
# #  > commanly used function
# #   1. relplot():
# # A high-level interface for drawing relational plots.
# # Examples: scatter plots, line plots.
# #   2. catplot():
# # A high-level interface for drawing categorical plots.
# # Examples: bar plots, box plots, violin plots.
# #   3.displot():
# # A high-level interface for drawing distributional plots.
# # Examples: histograms, KDE plots, rug plots.
# #  4.pairplot():
# #  A function for visualizing pairwise relationships in a dataset.
# #  Generates a matrix of plots to show relationships between each pair of variables.
# # 5. heatmap():
# # A function for drawing heatmaps.
# # Useful for visualizing correlation matrices or frequency tables.

# %% [markdown]
# # 1. relplot():

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data = sns.load_dataset("tips")
sns.lmplot(x="total_bill", y="tip", data=data)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset("tips")
sns.catplot(x="day", y="total_bill", hue="sex", kind="bar", data=tips, palette="muted", height=6, aspect=1.5)
plt.show()
# Out:
# C:\Users\Payal\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\Payal\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset("tips")
sns.displot(tips["total_bill"], kind="kde", fill=True, color="purple", height=6, aspect=1.5)
plt.show()
# Out:
# C:\Users\Payal\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import seaborn as sns
import matplotlib.pyplot as plt
iris = sns.load_dataset("iris")
sns.pairplot(iris, hue="species", kind="reg", markers=["o", "s", "D"], palette="husl")
plt.show()
# Out:
# C:\Users\Payal\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Payal\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Payal\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
data = np.random.rand(10, 12)
sns.heatmap(data)
plt.show()
