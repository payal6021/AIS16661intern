# %% [markdown]
# #        Mat Plot lib

# %% [markdown]
# # > to visialize data or to plot the data we used to Matplotlib
# # > matplotlib is a ploting library for python and its mathmatical numeric extention numpy.

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.8.0'

# %% [markdown]
# # 1. Pyplot

# %% [markdown]
# #pyplot is a module in matplotlib package which provides a simple function to add plot elements like lines images, text, etc to the current axes in the current figure

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[4,5,6,7],color="red")
plt.ylabel("y label")
plt.xlabel("x label")
plt.title("First plot")
plt.show()

# %% [markdown]
# # 2. scatter plot

# %%
import matplotlib.pyplot as plt
x = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11]
y = [99, 86, 87, 88, 100, 86, 103, 87, 94, 78]
plt.scatter(x, y)
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Scatter Plot Example')
plt.show()

# %% [markdown]
# # BAR plot

# %%
import matplotlib.pyplot as plt
categories = ['A', 'B', 'C', 'D', 'E']
values = [5, 7, 8, 2, 6]
plt.bar(categories, values)
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart Example')
plt.show()

# %%
import matplotlib.pyplot as plt
labels = ['A', 'B', 'C', 'D']
sizes = [15, 30, 45, 10]
plt.pie(sizes, labels=labels , autopct='%1.1f%%',startangle=140)
plt.title('Pie Chart Example')
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y1 = [1, 4, 9, 16, 25]
y2 = [1, 3, 6, 10, 15]
fig, axs = plt.subplots(2)
axs[0].plot(x, y1, 'b-o')
axs[0].set_title('Squared')
axs[1].plot(x, y2, 'r-^')
axs[1].set_title('Triangular')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data = np.random.randn(100)
plt.boxplot(data)
plt.title('Box Plot Example')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data = np.random.rand(10, 10)
plt.imshow(data, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.title('Heatmap Example')
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = np.sin(np.sqrt(x**2 + y**2))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='viridis')
plt.title('3D Plot Example')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 2*np.pi, 100)
y1, y2 = np.sin(x), np.cos(x)
plt.plot(x, y1, label='Sin(x)', color='b')
plt.plot(x, y2, label='Cos(x)', color='r', linestyle='--')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Multiple Lines Plot')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y1 = [1, 2, 4, 8, 16]
y2 = [1, 3, 6, 10, 15]
plt.fill_between(x, y1, y2, color='skyblue', alpha=0.4)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Filled Area Plot Example')
plt.show()

# %%
# error plot visualizing the Variability in the data
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 10, 10)
y = np.sin(x)
error = 0.1 + 0.1 * np.sqrt(x)
plt.errorbar(x, y, yerr=error, fmt='-o')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Error Bars Example')
plt.show()
